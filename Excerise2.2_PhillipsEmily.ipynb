# %% [markdown]
# Read the .jsonl file into a DataFrame

# %%
#Libraries
import pandas as pd
import json
import string
import numpy as np

# %%
#Using read_json function to read .jsonl file into dataframe
#lines=True allows for reading the json file per line
contr_df = pd.read_json('controversial-comments.jsonl',lines=True)

#Viewing the data
print(contr_df.head())
# Out:
#    con                                                txt
# 0    0  Well it's great that he did something about th...
# 1    0                       You are right Mr. President.
# 2    0  You have given no input apart from saying I am...
# 3    0  I get the frustration but the reason they want...
# 4    0  I am far from an expert on TPP and I would ten...

# %% [markdown]
# Convert all text to lowercase letters

# %%
#Function for converting all text to lowercase letters
def lowerCase(string: str) -> str:
    #String lower function
    return string.lower()

#Apply the function
#Setting equal to 'txt' column in dataframe since it's being update
contr_df['txt'] = [lowerCase(string) for string in contr_df.txt]

# %% [markdown]
# Remove all punctuation from the text

# %%
#Function which removes all punctuation from a string of text
#maketrans --> returns a mapping table for translation, used by translate method
#Translates punctuation to nothing
def remove_punctuation(text: str) -> str:
    return text.translate(str.maketrans('', '', string.punctuation))

#Removing punctuation from contr_dr.txt
contr_df['txt'] = [remove_punctuation(text) for text in contr_df.txt]

# %% [markdown]
# Remove stop words

# %%
#Load library
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
#Downloading set of stop words
import nltk
#nltk.download('stopwords')
#nltk.download('punkt')

# %%
#Load stop words
stop_words = stopwords.words('english')

#Getting tokenized words -- tokenized copy of the text
contr_df['txt'] = contr_df['txt'].apply(word_tokenize)

# %%
#Removing stop words
contr_df['txt'] = [word for word in contr_df.txt if word not in stop_words]

# %%
contr_df
# Out:
#         con                                                txt
# 0         0  [well, its, great, that, he, did, something, a...
# 1         0                   [you, are, right, mr, president]
# 2         0  [you, have, given, no, input, apart, from, say...
# 3         0  [i, get, the, frustration, but, the, reason, t...
# 4         0  [i, am, far, from, an, expert, on, tpp, and, i...
# ...     ...                                                ...
# 949995    0  [i, genuinely, cant, understand, how, anyone, ...
# 949996    0  [as, a, reminder, this, subreddit, is, for, ci...
# 949997    0              [k, dont, explain, why, or, anything]
# 949998    0                                          [deleted]
# 949999    0  [ya, sociopaths, are, known, for, celebrating,...
#
# [950000 rows x 2 columns]

# %% [markdown]
# Apply NLTK's PorterStemmer

# %%
from nltk.stem.porter import PorterStemmer
#Already have word tokens from above piece of code

#Create stemmer
porter = PorterStemmer()

#Applying the stemmer
#Stems are created by removing the suffixes or prefixes used with a word
contr_df['txt'] = [[porter.stem(word) for word in words] for words in contr_df['txt']]

# %%
contr_df['txt']
# Out:
# 0         [well, it, great, that, he, did, someth, about...
# 1                             [you, are, right, mr, presid]
# 2         [you, have, given, no, input, apart, from, say...
# 3         [i, get, the, frustrat, but, the, reason, they...
# 4         [i, am, far, from, an, expert, on, tpp, and, i...
#                                 ...
# 949995    [i, genuin, cant, understand, how, anyon, can,...
# 949996    [as, a, remind, thi, subreddit, is, for, civil...
# 949997                   [k, dont, explain, whi, or, anyth]
# 949998                                              [delet]
# 949999    [ya, sociopath, are, known, for, celebr, their...
# Name: txt, Length: 950000, dtype: object

# %% [markdown]
# #### Three Different Techniques

# %% [markdown]
# Convert each text entry into a word-count vector

# %%
from sklearn.feature_extraction.text import CountVectorizer
#nltk.download('averaged_perceptron_tagger')

# %%
#Create text
#Joining together words in each row of the dataframe to have lines of text

#Selecting 50,000 rows randomly for processing purposes
contr_df_sample = contr_df.sample(n=25000)
text_data = contr_df_sample['txt'].str.join(" ")
#text_data = [item for sublist in contr_df_sample['txt'] for item in sublist]

text_data
# Out:
# 749532    i think we should look into the speech that wa...
# 769468    when did i say i thought that your make shit u...
# 814707                                           pleas dont
# 771241    and sinc he do thi on hi vacat day it cost us ...
# 845809    there is also the invers of the silver line ca...
#                                 ...
# 381443    thi is all becaus of the incred danger idea th...
# 623374                                             well see
# 97050     elon musk wa also ad to trump advisori council...
# 356481    tldr what you wrote wa probabl dumb abort is w...
# 444808    isnt thi a way to keep econom anxieti high unt...
# Name: txt, Length: 25000, dtype: object

# %%
#Creating the bag of words feature matrix
count = CountVectorizer()
bag_of_words = count.fit_transform(text_data)

#View feature matrix
#Using sorted on keys to preserve the same order as count.get_feature_names()
#feature_names = sorted(count.vocabulary_.keys())
#pd.DataFrame(bag_of_words.toarray(),columns=feature_names)
list(zip(count.get_feature_names(), bag_of_words.sum(0).getA1()))
# Out:
# [('00', 3),
#  ('000', 3),
#  ('00000038', 1),
#  ('000327', 1),
#  ('0013157894736842', 1),
#  ('005', 2),
#  ('006', 1),
#  ('00712', 1),
#  ('00811', 1),
#  ('009', 2),
#  ('00946', 1),
#  ('01', 5),
#  ('010', 1),
#  ('016', 1),
#  ('01664', 1),
#  ('01857', 1),
#  ('02', 2),
#  ('025c', 1),
#  ('02683', 1),
#  ('03', 5),
#  ('0311', 1),
#  ('03285', 1),
#  ('037', 2),
#  ('04', 1),
#  ('04583', 1),
#  ('04917', 1),
#  ('05', 3),
#  ('05078', 1),
#  ('05092', 1),
#  ('05112', 1),
#  ('05143', 1),
#  ('05153', 1),
#  ('05162013', 1),
#  ('05409', 1),
#  ('06', 2),
#  ('06048', 1),
#  ('06249', 1),
#  ('07', 1),
#  ('07422', 1),
#  ('07882', 1),
#  ('08', 14),
#  ('0810', 1),
#  ('09', 3),
#  ('090', 1),
#  ('09302001', 1),
#  ('09302009', 1),
#  ('09302015', 1),
#  ('0g', 1),
#  ('0httpwwwpolitifactcompunditfactstatements2016nov18blogpostingno3millionundocumentedimmigrantsdidnotvot',
#   1),
#  ('10', 165),
#  ('100', 167),
#  ('1000', 23),
#  ('10000', 12),
#  ('100000', 12),
#  ('1000000', 1),
#  ('10000000', 1),
#  ('1001', 2),
#  ('100200k', 1),
#  ('10022', 1),
#  ('100f', 1),
#  ('100k', 11),
#  ('100m', 1),
#  ('100mbp', 1),
#  ('100myr', 1),
#  ('100pound', 1),
#  ('100visit', 1),
#  ('101', 13),
#  ('1010', 3),
#  ('1012', 3),
#  ('10132016', 2),
#  ('1015', 1),
#  ('1015165', 1),
#  ('10172004', 1),
#  ('102', 4),
#  ('1020', 2),
#  ('1020k', 1),
#  ('1020x', 1),
#  ('102913', 1),
#  ('102bn', 1),
#  ('103', 2),
#  ('1032', 1),
#  ('1040', 2),
#  ('1048', 1),
#  ('104b', 1),
#  ('105', 3),
#  ('1050', 1),
#  ('1051511', 1),
#  ('106', 1),
#  ('1069', 1),
#  ('107287', 1),
#  ('108', 1),
#  ('1080', 1),
#  ('109510', 1),
#  ('1099', 1),
#  ('10am', 1),
#  ('10billion', 1),
#  ('10c', 1),
#  ('10day', 1),
#  ('10httpswwwthebalancecomdeficitbypresidentwhatbudgetdeficitshide3306151', 1),
#  ('10k', 4),
#  ('10pm', 1),
#  ('10s100', 1),
#  ('10th', 1),
#  ('10thfriendli', 1),
#  ('10x', 1),
#  ('10yearold', 1),
#  ('11', 46),
#  ('110', 5),
#  ('11000', 1),
#  ('110000', 2),
#  ('11000000', 1),
#  ('111', 4),
#  ('1114', 1),
#  ('112', 1),
#  ('1143', 1),
#  ('114yearsold', 1),
#  ('11563931', 1),
#  ('1159', 1),
#  ('116', 1),
#  ('116th', 1),
#  ('117', 1),
#  ('1175k', 1),
#  ('118', 1),
#  ('119', 2),
#  ('1190982900351175', 1),
#  ('11hr', 1),
#  ('11k', 1),
#  ('11m', 1),
#  ('11month', 1),
#  ('11point', 1),
#  ('11th', 6),
#  ('12', 61),
#  ('120', 2),
#  ('1200', 5),
#  ('12000', 3),
#  ('12000httpswwwthenationcomarticlehowthe2000electioninfloridaledtoanewwaveofvoterdisenfranchis',
#   1),
#  ('12116', 1),
#  ('1214', 1),
#  ('121bb', 1),
#  ('123', 2),
#  ('1233', 1),
#  ('129000246000httpsenwikipediaorgwikiatomicbombingsofhiroshimaandnagasaki',
#   1),
#  ('1299', 3),
#  ('12a', 1),
#  ('12b', 1),
#  ('12bn', 1),
#  ('12httpreddit5tn2m3', 1),
#  ('12httpsenwikipediaorgwikinorthcarolina27s12thcongressionaldistrict', 1),
#  ('12k', 1),
#  ('12point', 1),
#  ('12th', 3),
#  ('12yearold', 3),
#  ('13', 27),
#  ('130', 1),
#  ('1300', 5),
#  ('130km', 1),
#  ('130m', 1),
#  ('131', 1),
#  ('13167', 1),
#  ('132', 1),
#  ('1323459', 1),
#  ('1328302', 1),
#  ('133', 1),
#  ('134', 1),
#  ('134113880', 1),
#  ('1341a', 1),
#  ('1347', 1),
#  ('13526', 1),
#  ('1364', 1),
#  ('139', 4),
#  ('13httpcdnphupicomsvemupiupi151140779163520141950eb4b89d02f6def7b31f9ae3f5de50fauxpasfewlaughingatpresidentsimpromptujokearchivejpg',
#   1),
#  ('13yearold', 4),
#  ('14', 40),
#  ('140', 2),
#  ('14000', 1),
#  ('1404054', 1),
#  ('1414', 1),
#  ('142', 4),
#  ('143', 1),
#  ('144', 1),
#  ('14688', 1),
#  ('1488er', 1),
#  ('1499', 2),
#  ('14point', 1),
#  ('14th', 5),
#  ('14yearold', 1),
#  ('15', 73),
#  ('150', 7),
#  ('1500', 4),
#  ('15000', 4),
#  ('150000', 3),
#  ('150ish', 1),
#  ('15154', 1),
#  ('1516', 1),
#  ('1520', 6),
#  ('1520k', 1),
#  ('152780', 1),
#  ('154', 2),
#  ('155', 1),
#  ('158', 2),
#  ('15agenc', 1),
#  ('15b', 1),
#  ('15hr', 3),
#  ('15httptaxfoundationorgarticle2016taxbracket', 1),
#  ('15k', 2),
#  ('15m', 2),
#  ('15minut', 1),
#  ('15year', 1),
#  ('15yearold', 3),
#  ('16', 31),
#  ('160', 1),
#  ('1600', 2),
#  ('16059km2', 1),
#  ('16300', 1),
#  ('164', 1),
#  ('16d', 1),
#  ('16day', 1),
#  ('16th', 2),
#  ('16yearold', 3),
#  ('17', 30),
#  ('170', 1),
#  ('1700', 1),
#  ('172', 1),
#  ('174', 1),
#  ('1755', 1),
#  ('175m', 1),
#  ('1776', 1),
#  ('17772017', 1),
#  ('17bil', 1),
#  ('17m', 1),
#  ('17th', 2),
#  ('18', 38),
#  ('180', 10),
#  ('1800', 3),
#  ('18000', 3),
#  ('1800000000', 1),
#  ('1812', 2),
#  ('1815061766648433', 1),
#  ('1821', 2),
#  ('1822', 1),
#  ('1824', 1),
#  ('1829', 1),
#  ('1829yearold', 1),
#  ('1833', 1),
#  ('1834', 2),
#  ('184', 1),
#  ('1845557', 1),
#  ('185', 2),
#  ('1860', 1),
#  ('1861', 1),
#  ('1864', 2),
#  ('1865', 1),
#  ('1866ourvot', 1),
#  ('1868', 2),
#  ('1870shttpwwwnytimescominteractive20161218uselectionsdonaldtrumpelectoralcollegepopularvotehtmlr2',
#   1),
#  ('18720', 1),
#  ('1876', 2),
#  ('188000', 1),
#  ('1887', 1),
#  ('1888', 2),
#  ('1891', 1),
#  ('18k', 1),
#  ('18th', 4),
#  ('18year', 1),
#  ('19', 13),
#  ('1900', 4),
#  ('19000', 1),
#  ('1901', 1),
#  ('1912', 1),
#  ('1913', 2),
#  ('1915', 1),
#  ('1916', 3),
#  ('1917', 1),
#  ('1920', 1),
#  ('1921', 1),
#  ('1922', 3),
#  ('1926', 1),
#  ('1929', 1),
#  ('193', 1),
#  ('1930', 5),
#  ('1930httpsfasorgissuesnuclearweaponsstatusworldnuclearforc', 1),
#  ('1932', 1),
#  ('1933', 5),
#  ('19331936', 1),
#  ('1936ish', 1),
#  ('1937', 1),
#  ('1938', 1),
#  ('19381945', 1),
#  ('1942', 1),
#  ('1943', 1),
#  ('1945', 2),
#  ('1946', 1),
#  ('19461964', 1),
#  ('1947', 1),
#  ('1948', 1),
#  ('195', 2),
#  ('1950', 5),
#  ('1951', 1),
#  ('1952', 1),
#  ('1953', 1),
#  ('1955', 2),
#  ('1956', 1),
#  ('196', 1),
#  ('1960', 5),
#  ('1962', 1),
#  ('1963', 1),
#  ('1964', 7),
#  ('1965', 1),
#  ('1966', 1),
#  ('1968', 3),
#  ('1970', 4),
#  ('1971', 1),
#  ('1972', 6),
#  ('1975', 2),
#  ('198', 1),
#  ('1980', 18),
#  ('19800', 1),
#  ('1980httpaphelisnetwpcontentuploads201204asimov1980cultofignorancepdf', 1),
#  ('19821988', 1),
#  ('1983', 1),
#  ('1984', 16),
#  ('1984ish', 1),
#  ('1985', 4),
#  ('1986', 1),
#  ('1988', 3),
#  ('1989', 3),
#  ('199', 1),
#  ('1990', 8),
#  ('1991', 1),
#  ('1992', 10),
#  ('1993', 3),
#  ('19932017', 1),
#  ('1994', 2),
#  ('1995', 4),
#  ('1996', 8),
#  ('1997', 2),
#  ('1998', 2),
#  ('1999', 4),
#  ('19th', 5),
#  ('1a', 1),
#  ('1b', 1),
#  ('1billion', 2),
#  ('1d', 2),
#  ('1er', 2),
#  ('1for38', 1),
#  ('1httptheglobalstatecommaincurrenteventsputinsnewauthoritarianrussia', 1),
#  ('1httpwebtampabaycomopinioneditorialseditorialhillaryclintonforthedemocraticnomination2265196',
#   1),
#  ('1httpwwwwnycorgstorybrooklynvoterpurgeageclintonsand', 1),
#  ('1k', 1),
#  ('1l', 1),
#  ('1m', 3),
#  ('1mday', 1),
#  ('1st', 19),
#  ('1to1', 1),
#  ('1you', 1),
#  ('1½', 1),
#  ('20', 144),
#  ('200', 13),
#  ('2000', 40),
#  ('20000', 3),
#  ('200000', 5),
#  ('200000th', 1),
#  ('2000month', 1),
#  ('2001', 11),
#  ('20012009', 2),
#  ('20014', 1),
#  ('2002', 22),
#  ('2003', 28),
#  ('200300', 1),
#  ('2004', 17),
#  ('2005', 21),
#  ('2006', 12),
#  ('2007', 10),
#  ('20072009', 1),
#  ('2008', 85),
#  ('200809', 1),
#  ('20082009', 1),
#  ('2009', 15),
#  ('200k', 10),
#  ('200lb', 1),
#  ('2010', 23),
#  ('2010httpwww2ucsceduwhorulesamericapowerwealthhtml', 1),
#  ('2011', 13),
#  ('2012', 59),
#  ('2013', 19),
#  ('2013right', 1),
#  ('2014', 32),
#  ('2014begin', 1),
#  ('2014httpsenwikipediaorgwikikansasgubernatorialelection2014results3', 1),
#  ('2014httpsenwikipediaorgwikipoliticalpartystrengthinusstatesgallup', 1),
#  ('2015', 35),
#  ('20152016', 1),
#  ('2016', 122),
#  ('2016httpwwwtandfonlinecomdoifull1010800096340220161145901', 2),
#  ('2016httpwwwtandfonlinecomdoipdf1010800096340220161145901', 1),
#  ('2016i', 1),
#  ('2017', 19),
#  ('2018', 43),
#  ('20182020', 3),
#  ('2019', 3),
#  ('202', 1),
#  ('2020', 93),
#  ('20202024', 1),
#  ('2024', 4),
#  ('2025', 1),
#  ('2030', 5),
#  ('2032', 1),
#  ('203383', 1),
#  ('203501', 1),
#  ('2050', 1),
#  ('2060httpwwwcensusgovcontentdamcensuslibrarypublications2015demop251143pdf',
#   1),
#  ('2071', 2),
#  ('208', 2),
#  ('208223', 1),
#  ('2086', 1),
#  ('20k', 1),
#  ('20kyear', 1),
#  ('20m', 2),
#  ('20mil', 2),
#  ('20second', 1),
#  ('20someth', 2),
#  ('20th', 10),
#  ('21', 18),
#  ('210', 1),
#  ('211', 1),
#  ('215', 2),
#  ('216', 1),
#  ('216b', 2),
#  ('218', 1),
#  ('21byear', 1),
#  ('21st', 7),
#  ('21stcenturi', 1),
#  ('22', 17),
#  ('22000', 1),
#  ('22191192', 1),
#  ('224', 2),
#  ('22423', 1),
#  ('225', 3),
#  ('226000', 1),
#  ('227', 1),
#  ('228', 1),
#  ('2282862', 1),
#  ('22m', 1),
#  ('22nd', 3),
#  ('22percentagepoint', 1),
#  ('22t', 1),
#  ('23', 20),
#  ('230', 3),
#  ('232', 3),
#  ('235', 1),
#  ('238', 1),
#  ('23k', 2),
#  ('23rd', 1),
#  ('23t', 1),
#  ('24', 38),
#  ('240', 3),
#  ('2400', 1),
#  ('240000', 1),
#  ('245am', 1),
#  ('247', 16),
#  ('248', 1),
#  ('249282', 1),
#  ('24hour', 1),
#  ('24m', 2),
#  ('25', 57),
#  ('250', 6),
#  ('2500', 2),
#  ('25000', 1),
#  ('250000', 3),
#  ('250k', 4),
#  ('250m', 1),
#  ('251', 1),
#  ('2537', 1),
#  ('2566', 1),
#  ('256d', 1),
#  ('2570httpsfasorgissuesnuclearweaponsstatusworldnuclearforc', 1),
#  ('2586', 1),
#  ('259', 1),
#  ('25k', 2),
#  ('25m', 1),
#  ('25th', 4),
#  ('26', 12),
#  ('263', 2),
#  ('264', 2),
#  ('2657', 1),
#  ('268', 2),
#  ('26m', 1),
#  ('26th', 1),
#  ('27', 16),
#  ('270', 21),
#  ('2700', 1),
#  ('27000', 2),
#  ('271266', 1),
#  ('271267', 1),
#  ('272', 1),
#  ('276877', 1),
#  ('28', 9),
#  ('280mil', 1),
#  ('280million', 1),
#  ('284', 1),
#  ('285', 1),
#  ('286', 1),
#  ('28th', 6),
#  ('29', 19),
#  ('290', 1),
#  ('2900', 1),
#  ('2987', 1),
#  ('299', 1),
#  ('2999', 1),
#  ('29th', 1),
#  ('2a', 1),
#  ('2d', 1),
#  ('2dayold', 1),
#  ('2h2', 1),
#  ('2httpsislimghxvo75png', 1),
#  ('2httpsthinkprogressorgtrumpmaralagoduestrumphotelsprofitoffpresidency92f33bf9f7fbc95gdmv3c',
#   1),
#  ('2httpswwwarchivesgovfoundingdocsconstitutiontranscripttocsection2', 1),
#  ('2httpswwwgooglecomampmobilenytimescom20161229uspoliticsrussiaelectionhackingsanctionsamphtml',
#   1),
#  ('2httptheweekcomspeedreads619577clintoncrushedsandersamongnewyorkblacklatinovotersaccordingexitpol',
#   1),
#  ('2httpwwwvoxcomworld20172214494478bowlinggreenmassacr', 1),
#  ('2i', 1),
#  ('2impli', 1),
#  ('2k', 1),
#  ('2mm', 2),
#  ('2nd', 33),
#  ('2s', 1),
#  ('2sentenc', 1),
#  ('2x', 5),
#  ('2yearold', 1),
#  ('30', 121),
#  ('300', 13),
#  ('3000', 9),
#  ('30000', 4),
#  ('300000', 2),
#  ('3000000', 1),
#  ('300000000', 1),
#  ('300k', 8),
#  ('30306', 1),
#  ('304', 3),
#  ('304224', 1),
#  ('304gt227', 1),
#  ('306', 5),
#  ('3060usd', 1),
#  ('306232', 1),
#  ('307', 2),
#  ('308', 1),
#  ('3091', 1),
#  ('30b', 1),
#  ('30daysincounti', 1),
#  ('30gb', 1),
#  ('30ish', 2),
#  ('30kyear', 1),
#  ('30m', 1),
#  ('30shigh', 1),
#  ('30some', 1),
#  ('30x', 1),
#  ('30year', 1),
#  ('30yearsold', 1),
#  ('31', 19),
#  ('31000', 1),
#  ('312', 1),
#  ('315', 1),
#  ('318', 1),
#  ('31st', 1),
#  ('32', 3),
#  ('320', 1),
#  ('3200', 3),
#  ('320m', 1),
#  ('321', 1),
#  ('3238', 1),
#  ('325', 2),
#  ('33', 8),
#  ('330', 3),
#  ('33000', 3),
#  ('333bb', 1),
#  ('337', 1),
#  ('33k', 2),
#  ('34', 10),
#  ('340', 1),
#  ('341', 1),
#  ('34region', 1),
#  ('35', 26),
#  ('350', 2),
#  ('3500', 1),
#  ('35000', 3),
#  ('3550', 1),
#  ('35k', 1),
#  ('35m', 1),
#  ('35th', 4),
#  ('35x', 1),
#  ('35yo', 1),
#  ('36', 10),
#  ('3600', 1),
#  ('363', 1),
#  ('36475', 1),
#  ('365d', 1),
#  ('366', 2),
#  ('36m', 1),
#  ('37', 13),
#  ('375', 1),
#  ('379', 1),
#  ('38', 6),
#  ('380', 1),
#  ('38000', 1),
#  ('382', 1),
#  ('39', 8),
#  ('391m', 1),
#  ('398', 1),
#  ('399', 1),
#  ('39th', 1),
#  ('3am', 4),
#  ('3billion', 1),
#  ('3d', 2),
#  ('3dgi', 1),
#  ('3h3', 1),
#  ('3httpwwwthedailybeastcomarticles20170208seanspicermakesupatlantaislamistattackhtml',
#   1),
#  ('3letter', 1),
#  ('3m', 1),
#  ('3million', 1),
#  ('3on1', 1),
#  ('3point', 1),
#  ('3rd', 57),
#  ('3s', 1),
#  ('3term', 1),
#  ('3x', 3),
#  ('3you', 1),
#  ('40', 66),
#  ('400', 12),
#  ('4000', 5),
#  ('40000', 1),
#  ('400000', 1),
#  ('4000000000', 1),
#  ('400bln', 1),
#  ('400httpgutenbergusarticlesinstitutionalrac', 1),
#  ('401k', 5),
#  ('4050', 2),
#  ('4060', 1),
#  ('4073', 1),
#  ('40acr', 1),
#  ('40g', 1),
#  ('40k', 1),
#  ('40person', 1),
#  ('40ton', 1),
#  ('41', 6),
#  ('4121922', 1),
#  ('41424km2', 1),
#  ('41593', 1),
#  ('42', 5),
#  ('424m', 1),
#  ('425', 1),
#  ('429', 1),
#  ('42nd', 2),
#  ('42point', 1),
#  ('43', 13),
#  ('438', 1),
#  ('44', 3),
#  ('440', 1),
#  ('442nd', 1),
#  ('443httpyoutubeous9mm8xbbw', 1),
#  ('449313', 1),
#  ('44b', 1),
#  ('44d', 1),
#  ('45', 21),
#  ('4500httpsfasorgissuesnuclearweaponsstatusworldnuclearforc', 1),
#  ('450k', 1),
#  ('45th', 1),
#  ('46', 12),
#  ('4615', 1),
#  ('4648', 1),
#  ('46th', 1),
#  ('47', 11),
#  ('473', 1),
#  ('47500', 1),
#  ('478', 1),
#  ('47m', 1),
#  ('48', 16),
#  ('4842', 1),
#  ('486', 1),
#  ('48m', 1),
#  ('48th', 1),
#  ('49', 9),
#  ('491', 2),
#  ('499', 1),
#  ('49yearold', 1),
#  ('4b', 1),
#  ('4chan', 10),
#  ('4cylind', 1),
#  ('4d', 4),
#  ('4edgy8m', 1),
#  ('4gallon', 1),
#  ('4httpwwwpoliticususacom20170203trumpbustedbigliegovernmentadmitscourt100000impactedmuslimbanhtml',
#   1),
#  ('4k', 1),
#  ('4m', 2),
#  ('4th', 13),
#  ('4to1', 1),
#  ('4vote', 1),
#  ('4way', 1),
#  ('50', 100),
#  ('500', 21),
#  ('5000', 7),
#  ('50000', 7),
#  ('500000', 9),
#  ('500040000', 1),
#  ('5000squarefoot', 1),
#  ('500k', 2),
#  ('500kday', 1),
#  ('500page', 1),
#  ('501', 1),
#  ('501c', 1),
#  ('501c3', 1),
#  ('501c4', 1),
#  ('502', 1),
#  ('5050', 9),
#  ('5055', 1),
#  ('5060', 1),
#  ('50cal', 1),
#  ('50k', 12),
#  ('50state', 1),
#  ('50th', 1),
#  ('50x', 1),
#  ('51', 9),
#  ('510', 3),
#  ('513', 1),
#  ('515', 3),
#  ('51k', 1),
#  ('52', 5),
#  ('523', 1),
#  ('525', 1),
#  ('5270', 1),
#  ('53', 3),
#  ('536', 1),
#  ('537', 1),
#  ('537000', 1),
#  ('538', 26),
#  ('538httpfivethirtyeightcomfeatureswhyfivethirtyeightgavetrumpabetterchancethanalmostanyoneels',
#   1),
#  ('538httpfivethirtyeightcomliveblog2016electionresultscoverageexcid538twitt',
#   1),
#  ('53k', 2),
#  ('54', 13),
#  ('540k', 1),
#  ('544k', 1),
#  ('545', 1),
#  ('545am', 1),
#  ('54k', 1),
#  ('55', 11),
#  ('550', 1),
#  ('5516', 1),
#  ('552', 1),
#  ('5543', 1),
#  ('56', 5),
#  ('560', 1),
#  ('569', 1),
#  ('56m', 1),
#  ('57', 8),
#  ('573', 1),
#  ('576', 1),
#  ('577', 1),
#  ('57th', 1),
#  ('58', 9),
#  ('580746341220006', 1),
#  ('582658', 1),
#  ('59', 5),
#  ('594', 1),
#  ('59th', 1),
#  ('5d', 1),
#  ('5hr', 1),
#  ('5m', 1),
#  ('5minut', 1),
#  ('5second', 1),
#  ('5th', 11),
#  ('60', 53),
#  ('600', 3),
#  ('6000', 4),
#  ('60000', 2),
#  ('600000', 4),
#  ('60000000', 2),
#  ('6001000', 1),
#  ('600k', 1),
#  ('6040', 3),
#  ('6071', 1),
#  ('607pm', 1),
#  ('60bil', 1),
#  ('60k', 2),
#  ('60m', 2),
#  ('60s70', 1),
#  ('60shttpimgurcoma6jq5o', 1),
#  ('60someth', 1),
#  ('61', 2),
#  ('610236559131169', 1),
#  ('6108', 1),
#  ('614', 1),
#  ('617', 1),
#  ('62', 1),
#  ('62235295', 1),
#  ('6240788662972578', 1),
#  ('626630', 1),
#  ('629', 2),
#  ('62k', 1),
#  ('62m', 1),
#  ('63', 5),
#  ('630', 1),
#  ('63148555', 1),
#  ('64', 4),
#  ('640', 1),
#  ('64235478', 1),
#  ('644', 1),
#  ('646449', 1),
#  ('64917448', 1),
#  ('64dd', 1),
#  ('64k', 1),
#  ('65', 9),
#  ('650', 4),
#  ('6500', 1),
#  ('65000', 2),
#  ('650000', 4),
#  ('650m', 1),
#  ('6535', 1),
#  ('656am', 1),
#  ('658', 1),
#  ('659', 1),
#  ('65915795', 1),
#  ('66', 5),
#  ('666', 1),
#  ('6695', 1),
#  ('66m', 1),
#  ('67', 13),
#  ('67500000', 1),
#  ('67httpswwwwashingtonpostcomnewsthefixwp20130123recordhighforhillaryclintonasshefaceslittleregardedcongress',
#   1),
#  ('67k', 1),
#  ('68', 3),
#  ('6800', 1),
#  ('68262', 1),
#  ('6850year', 1),
#  ('6885', 1),
#  ('69', 5),
#  ('6970httpwwwtandfonlinecomdoifull1010800096340220161145901', 1),
#  ('69th', 1),
#  ('6in10', 1),
#  ('6k', 1),
#  ('6month', 1),
#  ('6th', 7),
#  ('70', 50),
#  ('700', 3),
#  ('7000', 5),
#  ('70000', 2),
#  ('700b', 1),
#  ('700k', 3),
#  ('700m', 1),
#  ('7046', 1),
#  ('7050', 1),
#  ('7063', 1),
#  ('7080', 1),
#  ('7090', 1),
#  ('70k', 1),
#  ('70m', 1),
#  ('70yearold', 1),
#  ('71', 6),
#  ('710', 1),
#  ('71000', 1),
#  ('72', 4),
#  ('721', 1),
#  ('723393', 1),
#  ('725', 2),
#  ('72716', 1),
#  ('7281922', 1),
#  ('73', 6),
#  ('730', 1),
#  ('732pm', 1),
#  ('735132', 1),
#  ('736', 1),
#  ('737', 1),
#  ('7384bjdoeu7863', 1),
#  ('739', 1),
#  ('7478the', 1),
#  ('7482', 1),
#  ('74httpswwwscribdcomfullscreen69765861accesskeykey1wzpikwzuir39w8uxutgampstartpage52',
#   1),
#  ('75', 14),
#  ('750k', 1),
#  ('751', 1),
#  ('754', 1),
#  ('7580', 1),
#  ('75billion', 1),
#  ('75k', 3),
#  ('75m', 1),
#  ('7643107', 1),
#  ('77', 1),
#  ('78', 5),
#  ('780', 1),
#  ('784000', 1),
#  ('785000', 1),
#  ('79', 3),
#  ('793', 1),
#  ('793f', 1),
#  ('795', 1),
#  ('7b', 1),
#  ('7mil', 1),
#  ('7minut', 1),
#  ('7th', 4),
#  ('80', 64),
#  ('800', 8),
#  ('8000', 1),
#  ('80000', 1),
#  ('800000', 1),
#  ('800k', 1),
#  ('800k1m', 1),
#  ('800mo', 1),
#  ('8020', 3),
#  ('8090', 1),
#  ('80k', 6),
#  ('80month', 1),
#  ('80searli', 1),
#  ('81', 6),
#  ('810', 1),
#  ('810m', 1),
#  ('824', 1),
#  ('83', 2),
#  ('832', 1),
#  ('835', 1),
#  ('844877', 1),
#  ('85', 7),
#  ('852000', 1),
#  ('86', 2),
#  ('862', 1),
#  ('8693', 1),
#  ('86d', 1),
#  ('86not', 1),
#  ('87', 1),
#  ('8750', 1),
#  ('88', 2),
#  ('8800', 1),
#  ('896', 1),
#  ('8am', 1),
#  ('8b', 1),
#  ('8d', 1),
#  ('8httpsmedia1britannicacomebmedia06380600404362630jpg', 1),
#  ('8ish', 1),
#  ('8k', 1),
#  ('8th', 14),
#  ('8x', 1),
#  ('8year', 1),
#  ('8yearold', 1),
#  ('8yr', 1),
#  ('90', 68),
#  ('900', 3),
#  ('9000', 1),
#  ('900b', 1),
#  ('900k', 1),
#  ('9010', 1),
#  ('9095', 1),
#  ('90th', 1),
#  ('91', 2),
#  ('910', 4),
#  ('911', 53),
#  ('912', 1),
#  ('915', 1),
#  ('916', 1),
#  ('92', 3),
#  ('925749', 1),
#  ('92f', 1),
#  ('93', 3),
#  ('933', 1),
#  ('94', 3),
#  ('9404', 1),
#  ('943', 1),
#  ('946', 1),
#  ('948', 1),
#  ('9486', 1),
#  ('95', 16),
#  ('950', 1),
#  ('95er', 1),
#  ('96', 3),
#  ('968440', 1),
#  ('97', 2),
#  ('979', 1),
#  ('98', 6),
#  ('982', 1),
#  ('98300', 1),
#  ('984', 1),
#  ('99', 28),
#  ('99000', 1),
#  ('99110', 1),
#  ('992', 1),
#  ('997', 3),
#  ('999', 2),
#  ('9999', 1),
#  ('999999', 1),
#  ('9hr', 1),
#  ('9httpgovinfolibraryuntedutaxreformpanelfinalreportindexhtml', 1),
#  ('9month', 1),
#  ('9th', 9),
#  ('aa', 3),
#  ('aaa', 1),
#  ('aaaaaaaaaaa', 1),
#  ('aaaaaaaaaand', 1),
#  ('aaaaaaaahahahahaha', 1),
#  ('aaaaaand', 1),
#  ('aaaaanndddit', 1),
#  ('aaaaannnnndddh', 1),
#  ('aaaand', 3),
#  ('aaand', 1),
#  ('aaron', 2),
#  ...]

# %% [markdown]
# Convert each text entry into a part-of-speech tag vector

# %%
from nltk import pos_tag

#Use pre-trained part of speech tagger
#Casting to string object
text_tagged = pos_tag(word_tokenize(str(text_data)))

#Show parts of speech
text_tagged
# Out:
# [('749532', 'CD'),
#  ('i', 'JJ'),
#  ('think', 'VBP'),
#  ('we', 'PRP'),
#  ('should', 'MD'),
#  ('look', 'VB'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('speech', 'NN'),
#  ('that', 'IN'),
#  ('wa', 'NN'),
#  ('...', ':'),
#  ('769468', 'CD'),
#  ('when', 'WRB'),
#  ('did', 'VBD'),
#  ('i', 'VB'),
#  ('say', 'VBP'),
#  ('i', 'JJ'),
#  ('thought', 'VBD'),
#  ('that', 'IN'),
#  ('your', 'PRP$'),
#  ('make', 'NN'),
#  ('shit', 'NN'),
#  ('u', 'NN'),
#  ('...', ':'),
#  ('814707', 'CD'),
#  ('pleas', 'NNS'),
#  ('dont', 'JJ'),
#  ('771241', 'CD'),
#  ('and', 'CC'),
#  ('sinc', 'VB'),
#  ('he', 'PRP'),
#  ('do', 'VB'),
#  ('thi', 'VB'),
#  ('on', 'IN'),
#  ('hi', 'JJ'),
#  ('vacat', 'NN'),
#  ('day', 'NN'),
#  ('it', 'PRP'),
#  ('cost', 'VBD'),
#  ('us', 'PRP'),
#  ('...', ':'),
#  ('845809', 'CD'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('the', 'DT'),
#  ('invers', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('silver', 'NN'),
#  ('line', 'NN'),
#  ('ca', 'MD'),
#  ('...', ':'),
#  ('...', ':'),
#  ('381443', 'CD'),
#  ('thi', 'NN'),
#  ('is', 'VBZ'),
#  ('all', 'DT'),
#  ('becaus', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('incred', 'JJ'),
#  ('danger', 'NN'),
#  ('idea', 'NN'),
#  ('th', 'NN'),
#  ('...', ':'),
#  ('623374', 'CD'),
#  ('well', 'RB'),
#  ('see', 'VB'),
#  ('97050', 'CD'),
#  ('elon', 'NN'),
#  ('musk', 'NN'),
#  ('wa', 'NN'),
#  ('also', 'RB'),
#  ('ad', 'NN'),
#  ('to', 'TO'),
#  ('trump', 'VB'),
#  ('advisori', 'JJ'),
#  ('council', 'NN'),
#  ('...', ':'),
#  ('356481', 'CD'),
#  ('tldr', 'NN'),
#  ('what', 'WP'),
#  ('you', 'PRP'),
#  ('wrote', 'VBD'),
#  ('wa', 'JJ'),
#  ('probabl', 'NN'),
#  ('dumb', 'JJ'),
#  ('abort', 'NN'),
#  ('is', 'VBZ'),
#  ('w', 'JJ'),
#  ('...', ':'),
#  ('444808', 'CD'),
#  ('isnt', 'NN'),
#  ('thi', 'VBD'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('keep', 'VB'),
#  ('econom', 'NN'),
#  ('anxieti', 'RB'),
#  ('high', 'JJ'),
#  ('unt', 'NN'),
#  ('...', ':'),
#  ('Name', 'NN'),
#  (':', ':'),
#  ('txt', 'NN'),
#  (',', ','),
#  ('Length', 'NNP'),
#  (':', ':'),
#  ('25000', 'CD'),
#  (',', ','),
#  ('dtype', 'NN'),
#  (':', ':'),
#  ('object', 'NN')]

# %% [markdown]
# Convert each entry into a term frequency-inverse document frequency (tf-idf) vector

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Create the tf-idf feature matrix
tfidf = TfidfVectorizer()
feature_matrix = tfidf.fit_transform(text_data)

# %%
#Show tf-idf feature matrix
#Using sorted on keys to preserve the same order as count.get_feature_names()
#feature_names = sorted(tfidf.vocabulary_.keys())
#feature_arr = feature_matrix.toarray()
#pd.DataFrame(feature_arr,columns=feature_names)
list(zip(tfidf.get_feature_names(), feature_matrix.sum(0).getA1()))
# Out:
# [('00', 0.8232030499681574),
#  ('000', 0.8837024905654752),
#  ('00000038', 0.08366034999796579),
#  ('000327', 0.11932289049751407),
#  ('0013157894736842', 0.42160000004428994),
#  ('005', 0.42005800769076085),
#  ('006', 0.25801503204430043),
#  ('00712', 0.6403297409233798),
#  ('00811', 0.6403297409233798),
#  ('009', 0.3544273066413389),
#  ('00946', 0.6403297409233798),
#  ('01', 0.8439840043509931),
#  ('010', 0.4238356951648405),
#  ('016', 0.24065478576430033),
#  ('01664', 0.6403297409233798),
#  ('01857', 0.6403297409233798),
#  ('02', 0.0649774910163946),
#  ('025c', 0.1484287986596958),
#  ('02683', 0.6403297409233798),
#  ('03', 1.15579878424359),
#  ('0311', 0.0675032842217596),
#  ('03285', 0.6403297409233798),
#  ('037', 0.4528034497749471),
#  ('04', 0.3052684898286773),
#  ('04583', 0.6403297409233798),
#  ('04917', 0.6403297409233798),
#  ('05', 0.45833139526004135),
#  ('05078', 0.6403297409233798),
#  ('05092', 0.6403297409233798),
#  ('05112', 0.6403297409233798),
#  ('05143', 0.6403297409233798),
#  ('05153', 0.6403297409233798),
#  ('05162013', 0.1788173901048822),
#  ('05409', 0.6403297409233798),
#  ('06', 0.4006629624675869),
#  ('06048', 0.6403297409233798),
#  ('06249', 0.6403297409233798),
#  ('07', 0.23479565978533443),
#  ('07422', 0.6403297409233798),
#  ('07882', 0.6403297409233798),
#  ('08', 3.169460503188572),
#  ('0810', 0.46445887915870093),
#  ('09', 0.42892289254828875),
#  ('090', 0.10123149930026225),
#  ('09302001', 0.18793324815198387),
#  ('09302009', 0.18793324815198387),
#  ('09302015', 0.18793324815198387),
#  ('0g', 0.5414731316904374),
#  ('0httpwwwpolitifactcompunditfactstatements2016nov18blogpostingno3millionundocumentedimmigrantsdidnotvot',
#   0.7669844010774665),
#  ('10', 27.587350205985985),
#  ('100', 30.432457360092616),
#  ('1000', 4.395925092271043),
#  ('10000', 2.6838946828705206),
#  ('100000', 2.515729257697905),
#  ('1000000', 0.22373696834654314),
#  ('10000000', 0.5150703453035349),
#  ('1001', 0.876395319825956),
#  ('100200k', 0.16147613192883298),
#  ('10022', 0.05063083414986515),
#  ('100f', 0.12683964185378307),
#  ('100k', 1.6974659491862603),
#  ('100m', 0.15621006913957625),
#  ('100mbp', 0.21964383460614123),
#  ('100myr', 0.5177619848806497),
#  ('100pound', 0.235394667323808),
#  ('100visit', 0.2150902148079184),
#  ('101', 2.9470650862644536),
#  ('1010', 1.8308186322867621),
#  ('1012', 0.4333566962505638),
#  ('10132016', 0.18829194224612644),
#  ('1015', 0.09167143642300944),
#  ('1015165', 0.15055219991530627),
#  ('10172004', 0.13660238669949182),
#  ('102', 0.5692547776710204),
#  ('1020', 0.8123227121361101),
#  ('1020k', 0.3067897698039375),
#  ('1020x', 0.3668754958978232),
#  ('102913', 0.1223255502923122),
#  ('102bn', 0.15865810049088747),
#  ('103', 0.5525029768721348),
#  ('1032', 0.19678818527061218),
#  ('1040', 0.6783763418482115),
#  ('1048', 0.6466017764132038),
#  ('104b', 0.11423709324528265),
#  ('105', 0.5004679222474091),
#  ('1050', 0.20177272291266965),
#  ('1051511', 0.15055219991530627),
#  ('106', 0.3309249280943006),
#  ('1069', 0.1998634336772465),
#  ('107287', 0.125819392905698),
#  ('108', 0.08386241777078547),
#  ('1080', 0.16555217320188995),
#  ('109510', 0.5142410463330677),
#  ('1099', 0.1331771853295892),
#  ('10am', 0.14385810246720776),
#  ('10billion', 0.21690036720245848),
#  ('10c', 0.314764545094511),
#  ('10day', 0.11585480743229419),
#  ('10httpswwwthebalancecomdeficitbypresidentwhatbudgetdeficitshide3306151',
#   0.3582270441490092),
#  ('10k', 0.9684245117526122),
#  ('10pm', 0.34900968483052724),
#  ('10s100', 0.34742142544612775),
#  ('10th', 0.4382835889126588),
#  ('10thfriendli', 0.11766178861756504),
#  ('10x', 0.35843170090362986),
#  ('10yearold', 0.5352273725931084),
#  ('11', 9.651472344301956),
#  ('110', 1.4186505912929226),
#  ('11000', 0.08359777878744669),
#  ('110000', 0.4146650547167252),
#  ('11000000', 0.3120291245466509),
#  ('111', 0.392708387779696),
#  ('1114', 0.33765735069537545),
#  ('112', 0.1378865997252259),
#  ('1143', 0.42169230017364856),
#  ('114yearsold', 0.1198955593327443),
#  ('11563931', 0.23667196622144115),
#  ('1159', 0.4002664200398202),
#  ('116', 0.22373696834654314),
#  ('116th', 0.33967728950440224),
#  ('117', 0.3940966835954639),
#  ('1175k', 0.08791326533047492),
#  ('118', 0.06316530580599404),
#  ('119', 0.9133066502957727),
#  ('1190982900351175', 0.18793324815198387),
#  ('11hr', 0.2638107054606765),
#  ('11k', 0.09359373164897127),
#  ('11m', 0.28242112870258707),
#  ('11month', 0.10212199028320984),
#  ('11point', 0.11672836288917383),
#  ('11th', 2.077309728337655),
#  ('12', 9.6286051035801),
#  ('120', 0.6614525580199526),
#  ('1200', 0.9102155698604364),
#  ('12000', 0.6933607598298048),
#  ('12000httpswwwthenationcomarticlehowthe2000electioninfloridaledtoanewwaveofvoterdisenfranchis',
#   0.14490944510936737),
#  ('12116', 0.11932289049751407),
#  ('1214', 0.2800874105689539),
#  ('121bb', 0.18096752887887546),
#  ('123', 0.6383551969172688),
#  ('1233', 0.21292534543144276),
#  ('129000246000httpsenwikipediaorgwikiatomicbombingsofhiroshimaandnagasaki',
#   0.0324887455081973),
#  ('1299', 0.5247107503637005),
#  ('12a', 0.04151297083046913),
#  ('12b', 0.15568111727799236),
#  ('12bn', 0.23724433788909316),
#  ('12httpreddit5tn2m3', 0.14215607514803022),
#  ('12httpsenwikipediaorgwikinorthcarolina27s12thcongressionaldistrict',
#   0.2525015695739646),
#  ('12k', 0.17909221320247304),
#  ('12point', 0.2664267901911546),
#  ('12th', 0.7731504519444786),
#  ('12yearold', 0.46793107317248583),
#  ('13', 4.829855300644037),
#  ('130', 0.18718909004273981),
#  ('1300', 1.3423458377781068),
#  ('130km', 0.07926732711913924),
#  ('130m', 0.31080641250880514),
#  ('131', 0.24546706265529222),
#  ('13167', 0.36731533185096643),
#  ('132', 0.215338208850522),
#  ('1323459', 0.15055219991530627),
#  ('1328302', 0.15055219991530627),
#  ('133', 0.24643377260391033),
#  ('134', 0.06924893119350733),
#  ('134113880', 0.10123149930026225),
#  ('1341a', 0.04151297083046913),
#  ('1347', 0.31234976109192975),
#  ('13526', 0.16446907535735164),
#  ('1364', 0.22501590392126675),
#  ('139', 0.28489057725510436),
#  ('13httpcdnphupicomsvemupiupi151140779163520141950eb4b89d02f6def7b31f9ae3f5de50fauxpasfewlaughingatpresidentsimpromptujokearchivejpg',
#   0.1934031226184337),
#  ('13yearold', 0.8618419678498193),
#  ('14', 6.583104603092578),
#  ('140', 0.28855749056532376),
#  ('14000', 0.3368965915009753),
#  ('1404054', 0.15055219991530627),
#  ('1414', 0.44902333964162366),
#  ('142', 0.35017653519814473),
#  ('143', 0.44431204760018067),
#  ('144', 0.4717730938070109),
#  ('14688', 0.20769305092592005),
#  ('1488er', 0.08059740302499149),
#  ('1499', 0.21761610897264244),
#  ('14point', 0.5929298149933055),
#  ('14th', 0.7782116451483523),
#  ('14yearold', 0.1198955593327443),
#  ('15', 12.566201806894203),
#  ('150', 0.9416555899746718),
#  ('1500', 0.6419850417549116),
#  ('15000', 0.9749639512002828),
#  ('150000', 0.9075833489074779),
#  ('150ish', 0.15360134897101974),
#  ('15154', 0.1728715944677079),
#  ('1516', 0.1052644248115167),
#  ('1520', 0.9251673845236412),
#  ('1520k', 0.5060830904906131),
#  ('152780', 0.10896628889363504),
#  ('154', 0.6222443732152865),
#  ('155', 0.3140116689981238),
#  ('158', 0.41279592014646127),
#  ('15agenc', 0.4981614568452872),
#  ('15b', 0.15568111727799236),
#  ('15hr', 0.5812167803975887),
#  ('15httptaxfoundationorgarticle2016taxbracket', 0.20769305092592005),
#  ('15k', 0.7730163420366772),
#  ('15m', 0.4855115383165064),
#  ('15minut', 0.10026767493057348),
#  ('15year', 0.3003283370347731),
#  ('15yearold', 0.5375143290541432),
#  ('16', 6.050963110106955),
#  ('160', 0.05063083414986515),
#  ('1600', 0.9605197491029775),
#  ('16059km2', 0.125819392905698),
#  ('16300', 0.19166445484317476),
#  ('164', 0.0324887455081973),
#  ('16d', 0.49086246674850104),
#  ('16day', 0.7588276936020208),
#  ('16th', 0.7367231200516771),
#  ('16yearold', 0.634114013525018),
#  ('17', 5.862187037643192),
#  ('170', 0.16416918853956328),
#  ('1700', 0.21073343444779857),
#  ('172', 0.06316530580599404),
#  ('174', 0.1015345364435982),
#  ('1755', 0.2877272923780381),
#  ('175m', 0.2521698470979594),
#  ('1776', 0.39743485674542617),
#  ('17772017', 0.8071822810852872),
#  ('17bil', 0.374832496090724),
#  ('17m', 0.4297453791642383),
#  ('17th', 0.6331196504921799),
#  ('18', 6.1334385032676275),
#  ('180', 1.7911688443457345),
#  ('1800', 0.6100645755722819),
#  ('18000', 1.023232147200533),
#  ('1800000000', 0.0324887455081973),
#  ('1812', 0.7556746268129002),
#  ('1815061766648433', 0.18793324815198387),
#  ('1821', 0.16693413814022884),
#  ('1822', 0.37964578230804663),
#  ('1824', 0.36639991350633794),
#  ('1829', 0.24171333467746253),
#  ('1829yearold', 0.16956840761694583),
#  ('1833', 0.25522959993893257),
#  ('1834', 0.8755625383719063),
#  ('184', 0.06316530580599404),
#  ('1845557', 0.23667196622144115),
#  ('185', 0.7845183875738282),
#  ('1860', 0.1605869301122849),
#  ('1861', 0.3544372165315063),
#  ('1864', 0.39991075071805876),
#  ('1865', 0.2934132348228203),
#  ('1866ourvot', 0.7071067811865475),
#  ('1868', 0.14312361190689796),
#  ('1870shttpwwwnytimescominteractive20161218uselectionsdonaldtrumpelectoralcollegepopularvotehtmlr2',
#   0.9000569864020843),
#  ('18720', 0.20769305092592005),
#  ('1876', 0.4158534093858074),
#  ('188000', 0.10896628889363504),
#  ('1887', 0.06164314973975997),
#  ('1888', 0.4158534093858074),
#  ('1891', 0.501176899293568),
#  ('18k', 0.4845886491527211),
#  ('18th', 1.6263553722402024),
#  ('18year', 0.2912885626824367),
#  ('19', 2.6600575574676837),
#  ('1900', 0.6359272430404204),
#  ('19000', 0.1330489446285584),
#  ('1901', 0.15433410286801422),
#  ('1912', 0.2551024429038435),
#  ('1913', 0.5011503123247408),
#  ('1915', 0.22185533991902923),
#  ('1916', 0.4604327847327684),
#  ('1917', 0.07146953839444344),
#  ('1920', 0.10829863045708203),
#  ('1921', 0.1402671397373308),
#  ('1922', 0.3770765988196422),
#  ('1926', 0.06164314973975997),
#  ('1929', 0.7616997622522866),
#  ('193', 0.125819392905698),
#  ('1930', 0.31951421110631356),
#  ('1930httpsfasorgissuesnuclearweaponsstatusworldnuclearforc',
#   0.0324887455081973),
#  ('1932', 0.27756381955508796),
#  ('1933', 1.030393177450017),
#  ('19331936', 0.1446684151148789),
#  ('1936ish', 0.19454826973124784),
#  ('1937', 0.1446684151148789),
#  ('1938', 0.2973670151131077),
#  ('19381945', 0.1446684151148789),
#  ('1942', 0.27756381955508796),
#  ('1943', 0.11197798227763005),
#  ('1945', 0.09589958417833373),
#  ('1946', 0.37455804953423244),
#  ('19461964', 0.09365056051231954),
#  ('1947', 0.10023803953336878),
#  ('1948', 0.5444852396990358),
#  ('195', 0.24136957816588306),
#  ('1950', 1.3416764841218463),
#  ('1951', 0.14945785656026783),
#  ('1952', 0.22912852954494453),
#  ('1953', 0.22689843127606216),
#  ('1955', 0.3567308381160641),
#  ('1956', 0.22912852954494453),
#  ('196', 0.2840031312389548),
#  ('1960', 1.0757509754775003),
#  ('1962', 0.2235939129660515),
#  ('1963', 0.3544372165315063),
#  ('1964', 1.2724026826552621),
#  ('1965', 0.16513975760881192),
#  ('1966', 0.5056895040321794),
#  ('1968', 0.7508652053279414),
#  ('1970', 0.6333635342285625),
#  ('1971', 0.06530437564816181),
#  ('1972', 1.1588875394144),
#  ('1975', 0.4031767510599139),
#  ('198', 0.21002900384538042),
#  ('1980', 3.634800034650473),
#  ('19800', 0.21002900384538042),
#  ('1980httpaphelisnetwpcontentuploads201204asimov1980cultofignorancepdf',
#   0.2474980396580489),
#  ('19821988', 0.22587732785362122),
#  ('1983', 0.11009743573596664),
#  ('1984', 3.8594994137922796),
#  ('1984ish', 0.06606326690940054),
#  ('1985', 0.6566783886250162),
#  ('1986', 0.16504432394881147),
#  ('1988', 1.3359097517934504),
#  ('1989', 1.218643887143755),
#  ('199', 0.24643377260391033),
#  ('1990', 1.6526019890903567),
#  ('1991', 0.16956840761694583),
#  ('1992', 1.9382552327943519),
#  ('1993', 0.36590859856174646),
#  ('19932017', 0.7181965907287714),
#  ('1994', 0.5121485840113965),
#  ('1995', 0.9303746544735223),
#  ('1996', 1.7529197155973202),
#  ('1997', 0.46495736665620835),
#  ('1998', 0.5545227128189484),
#  ('1999', 0.49855799373476317),
#  ('19th', 0.8653715177150078),
#  ('1a', 0.4292391934463218),
#  ('1b', 0.697512645539823),
#  ('1billion', 0.34877783115865524),
#  ('1d', 0.7032184937724945),
#  ('1er', 0.35155243533044905),
#  ('1for38', 0.28654364860632886),
#  ('1httptheglobalstatecommaincurrenteventsputinsnewauthoritarianrussia',
#   0.12262669703228725),
#  ('1httpwebtampabaycomopinioneditorialseditorialhillaryclintonforthedemocraticnomination2265196',
#   0.14779341460209863),
#  ('1httpwwwwnycorgstorybrooklynvoterpurgeageclintonsand', 0.07230609933632551),
#  ('1k', 0.4527859877472262),
#  ('1l', 0.1718984805246748),
#  ('1m', 0.7958647665670768),
#  ('1mday', 0.11519485840024345),
#  ('1st', 3.3959774755842616),
#  ('1to1', 0.2527726128833387),
#  ('1you', 0.1012704799555854),
#  ('1½', 0.14780293527889996),
#  ('20', 23.706509495510463),
#  ('200', 2.639637944371925),
#  ('2000', 7.351825699833263),
#  ('20000', 0.7580392773124909),
#  ('200000', 1.3842302344352295),
#  ('200000th', 0.5639499222413885),
#  ('2000month', 0.13941960349308113),
#  ('2001', 0.47580670163035116),
#  ('20012009', 0.37942130345307334),
#  ('20014', 0.1266303391810334),
#  ('2002', 0.9726592761551347),
#  ('2003', 2.066293875177502),
#  ('200300', 0.06711800087493142),
#  ('2004', 1.9890503428232083),
#  ('2005', 1.786508560094078),
#  ('2006', 2.4165859950280995),
#  ('2007', 1.9754880308985583),
#  ('20072009', 0.04474148663887522),
#  ('2008', 15.353056458348515),
#  ('200809', 0.07482407971014747),
#  ('20082009', 0.2614608466324406),
#  ('2009', 2.633288022220205),
#  ('200k', 2.510938829512384),
#  ('200lb', 0.20856167287199964),
#  ('2010', 5.334465974324399),
#  ('2010httpwww2ucsceduwhorulesamericapowerwealthhtml', 0.14589541991530966),
#  ('2011', 2.0941932649903183),
#  ('2012', 9.893936265913103),
#  ('2013', 2.6552637663274483),
#  ('2013right', 0.5739825647422498),
#  ('2014', 5.216080983302525),
#  ('2014begin', 0.4117861730969816),
#  ('2014httpsenwikipediaorgwikikansasgubernatorialelection2014results3',
#   0.1609324050443791),
#  ('2014httpsenwikipediaorgwikipoliticalpartystrengthinusstatesgallup',
#   0.20983331334100302),
#  ('2015', 4.837169953161747),
#  ('20152016', 0.4468075456555693),
#  ('2016', 21.603945450730954),
#  ('2016httpwwwtandfonlinecomdoifull1010800096340220161145901',
#   0.0649774910163946),
#  ('2016httpwwwtandfonlinecomdoipdf1010800096340220161145901',
#   0.0324887455081973),
#  ('2016i', 0.5002673654204453),
#  ('2017', 4.851114942781396),
#  ('2018', 10.052076478513325),
#  ('20182020', 0.5825123834461645),
#  ('2019', 0.9591191728948937),
#  ('202', 0.37311523397219737),
#  ('2020', 23.56311412821232),
#  ('20202024', 0.45415919457639725),
#  ('2024', 1.3413628524350583),
#  ('2025', 0.13458855830495065),
#  ('2030', 1.0315766034726481),
#  ('2032', 0.20409379418900594),
#  ('203383', 0.10123149930026225),
#  ('203501', 0.10023803953336878),
#  ('2050', 0.230361915584555),
#  ('2060httpwwwcensusgovcontentdamcensuslibrarypublications2015demop251143pdf',
#   0.230361915584555),
#  ('2071', 0.3256712836680371),
#  ('208', 0.43949198347213225),
#  ('208223', 0.12591801179719972),
#  ('2086', 0.06924893119350733),
#  ('20k', 0.09359373164897127),
#  ('20kyear', 0.15303394490559635),
#  ('20m', 1.0586339350874021),
#  ('20mil', 0.3198448797330106),
#  ('20second', 0.24801078952809902),
#  ('20someth', 0.7249939996986229),
#  ('20th', 2.655865055406342),
#  ('21', 2.485585662313366),
#  ('210', 0.3690203230599185),
#  ('211', 0.06874351681367162),
#  ('215', 0.33416348061708323),
#  ('216', 0.38117035834579927),
#  ('216b', 0.5796419102717135),
#  ('218', 0.13914036946149677),
#  ('21byear', 0.043715733764776776),
#  ('21st', 2.0272773620642206),
#  ('21stcenturi', 0.24935817515209213),
#  ('22', 2.927571243705387),
#  ('22000', 0.16599343118068283),
#  ('22191192', 0.16138310294369373),
#  ('224', 0.4010862208379369),
#  ('22423', 0.125819392905698),
#  ('225', 1.2753023630480884),
#  ('226000', 0.920919975769122),
#  ('227', 0.3440830947857204),
#  ('228', 0.13109097483223575),
#  ('2282862', 0.37311523397219737),
#  ('22m', 0.14830335311045725),
#  ('22nd', 0.8421234053695162),
#  ('22percentagepoint', 0.16255317600925734),
#  ('22t', 0.43575482644452673),
#  ('23', 3.384309578796204),
#  ('230', 1.0517368197473493),
#  ('232', 0.469071738581744),
#  ('235', 0.06717482035958215),
#  ('238', 0.06316530580599404),
#  ('23k', 0.23103053536650714),
#  ('23rd', 0.11005876465509574),
#  ('23t', 0.43575482644452673),
#  ('24', 5.519584733851822),
#  ('240', 0.6414144040145501),
#  ('2400', 0.3412870778545004),
#  ('240000', 0.2679609249142554),
#  ('245am', 0.38572343208241067),
#  ('247', 3.26170346043404),
#  ('248', 0.2927150031557173),
#  ('249282', 0.10123149930026225),
#  ('24hour', 0.15287259862918462),
#  ('24m', 0.3124201382791525),
#  ('25', 8.480795186004963),
#  ('250', 1.6050899932100398),
#  ('2500', 0.5596284085251885),
#  ('25000', 0.37487268578894206),
#  ('250000', 0.634682641929557),
#  ('250k', 0.6272644441962694),
#  ('250m', 0.043715733764776776),
#  ('251', 0.570319105757791),
#  ('2537', 0.07774808979240357),
#  ('2566', 0.07774808979240357),
#  ('256d', 0.25838647565754924),
#  ('2570httpsfasorgissuesnuclearweaponsstatusworldnuclearforc',
#   0.0324887455081973),
#  ('2586', 0.06874351681367162),
#  ('259', 0.07774808979240357),
#  ('25k', 0.28410669958175366),
#  ('25m', 0.2559361920144063),
#  ('25th', 0.48039533087678304),
#  ('26', 2.7675446909226524),
#  ('263', 0.1899628689635501),
#  ('264', 0.1152210266107996),
#  ('2657', 0.07394916916915911),
#  ('268', 0.2577610904644159),
#  ('26m', 0.4818494911772921),
#  ('26th', 0.0828730626848605),
#  ('27', 3.2831244276805593),
#  ('270', 4.868942058000435),
#  ('2700', 0.2632594398876455),
#  ('27000', 0.4387351330831825),
#  ('271266', 0.19728261319401336),
#  ('271267', 0.169306390930849),
#  ('272', 0.07774808979240357),
#  ('276877', 0.10123149930026225),
#  ('28', 2.6834138251409287),
#  ('280mil', 0.1599224398665053),
#  ('280million', 0.1599224398665053),
#  ('284', 0.6034578250687106),
#  ('285', 0.14261563283076248),
#  ('286', 0.06316530580599404),
#  ('28th', 2.636299902020005),
#  ('29', 3.802249152575498),
#  ('290', 0.21690036720245848),
#  ('2900', 0.30547224904471815),
#  ('2987', 0.23580520584420825),
#  ('299', 0.06874351681367162),
#  ('2999', 0.09323780892921874),
#  ('29th', 0.4903869385830472),
#  ('2a', 0.1345301783642305),
#  ('2d', 0.12578933384560495),
#  ('2dayold', 0.414135272653853),
#  ('2h2', 0.14303759611719327),
#  ('2httpsislimghxvo75png', 0.14779341460209863),
#  ('2httpsthinkprogressorgtrumpmaralagoduestrumphotelsprofitoffpresidency92f33bf9f7fbc95gdmv3c',
#   0.03162041164366316),
#  ('2httpswwwarchivesgovfoundingdocsconstitutiontranscripttocsection2',
#   0.10548174434893076),
#  ('2httpswwwgooglecomampmobilenytimescom20161229uspoliticsrussiaelectionhackingsanctionsamphtml',
#   0.12262669703228725),
#  ('2httptheweekcomspeedreads619577clintoncrushedsandersamongnewyorkblacklatinovotersaccordingexitpol',
#   0.07230609933632551),
#  ('2httpwwwvoxcomworld20172214494478bowlinggreenmassacr', 0.03162041164366316),
#  ('2i', 0.1012704799555854),
#  ('2impli', 0.1189265611494623),
#  ('2k', 0.3192202588422564),
#  ('2mm', 0.2924772825026379),
#  ('2nd', 5.8640455374102824),
#  ('2s', 0.06316530580599404),
#  ('2sentenc', 0.16363891155906776),
#  ('2x', 1.2485448924539604),
#  ('2yearold', 0.35848926982340273),
#  ('30', 21.231826499730367),
#  ('300', 2.730019910711261),
#  ('3000', 1.7881144667909072),
#  ('30000', 0.793579370056404),
#  ('300000', 0.3459932434442303),
#  ('3000000', 0.44528196401111236),
#  ('300000000', 0.13852432547490673),
#  ('300k', 1.4141777290934066),
#  ('30306', 0.7048500000127608),
#  ('304', 0.8251199505455855),
#  ('304224', 0.39356983067679185),
#  ('304gt227', 1.0),
#  ('306', 1.0147356886319634),
#  ('3060usd', 0.3096373976381862),
#  ('306232', 0.48739123277845053),
#  ('307', 0.2518245886562851),
#  ('308', 0.24033884351196),
#  ('3091', 0.1998634336772465),
#  ('30b', 0.44739748938358187),
#  ('30daysincounti', 0.30844252785989923),
#  ('30gb', 0.15478438261637342),
#  ('30ish', 0.6466421518590193),
#  ('30kyear', 0.2834905376822187),
#  ('30m', 0.28242112870258707),
#  ('30shigh', 0.25022981264390864),
#  ('30some', 0.169306390930849),
#  ('30x', 0.13802043413162013),
#  ('30year', 0.3374823905634432),
#  ('30yearsold', 0.16956840761694583),
#  ('31', 3.5807578572088374),
#  ('31000', 0.4256281741177369),
#  ('312', 0.06464931824525134),
#  ('315', 0.28201048339589),
#  ('318', 0.29045792583965935),
#  ('31st', 0.025121423676799808),
#  ('32', 0.7825876757837256),
#  ('320', 0.38699870956234056),
#  ('3200', 0.9213728801535893),
#  ('320m', 0.08577408389240598),
#  ('321', 0.46577450150627897),
#  ('3238', 0.3807476773790103),
#  ('325', 0.05113443772569929),
#  ('33', 1.6799407721468413),
#  ('330', 1.7922908027384619),
#  ('33000', 0.7463126255340955),
#  ('333bb', 0.18096752887887546),
#  ('337', 0.08366034999796579),
#  ('33k', 0.43901364311289653),
#  ('34', 1.7395395983759145),
#  ('340', 0.10023803953336878),
#  ('341', 0.2840031312389548),
#  ('34region', 0.5605661661055267),
#  ('35', 4.412236489968108),
#  ('350', 0.2665911152202726),
#  ('3500', 0.2767537553426331),
#  ('35000', 0.5302524636806374),
#  ('3550', 0.11247643217552197),
#  ('35k', 0.24707274429901074),
#  ('35m', 0.3993372733098996),
#  ('35th', 1.4690714351869394),
#  ('35x', 0.3105122984150141),
#  ('35yo', 0.24194820348665305),
#  ('36', 1.5325249919040695),
#  ('3600', 0.28384275518586327),
#  ('363', 0.06316530580599404),
#  ('36475', 0.4819362535752726),
#  ('365d', 0.3669708942873715),
#  ('366', 0.11248018883619178),
#  ('36m', 0.2521698470979594),
#  ('37', 2.2884457595206094),
#  ('375', 0.06316530580599404),
#  ('379', 0.06874351681367162),
#  ('38', 1.307901268492531),
#  ('380', 0.123879710706449),
#  ('38000', 0.1558396370127976),
#  ('382', 0.13109097483223575),
#  ('39', 1.6271704687814061),
#  ('391m', 0.43575482644452673),
#  ('398', 0.06316530580599404),
#  ('399', 0.1331771853295892),
#  ('39th', 0.19454826973124784),
#  ('3am', 0.776120597823867),
#  ('3billion', 0.14597961908253632),
#  ('3d', 0.7458854184076407),
#  ('3dgi', 0.4827475823891102),
#  ('3h3', 0.14303759611719327),
#  ('3httpwwwthedailybeastcomarticles20170208seanspicermakesupatlantaislamistattackhtml',
#   0.03162041164366316),
#  ('3letter', 0.12788319473124019),
#  ('3m', 0.09796019677311282),
#  ('3million', 0.5470344765835575),
#  ('3on1', 0.5259615597373866),
#  ('3point', 0.6079148908696627),
#  ('3rd', 10.19161773290632),
#  ('3s', 0.3264790955907971),
#  ('3term', 0.1655349127085793),
#  ('3x', 0.4546881394474309),
#  ('3you', 0.1012704799555854),
#  ('40', 14.464900786418063),
#  ('400', 2.218386443360793),
#  ('4000', 1.2698940128358036),
#  ('40000', 0.4464591687250113),
#  ('400000', 0.10605089962170118),
#  ('4000000000', 0.2469440490557042),
#  ('400bln', 0.2275711635615718),
#  ('400httpgutenbergusarticlesinstitutionalrac', 0.13665763226772962),
#  ('401k', 0.9966479721090853),
#  ('4050', 0.3424159669150157),
#  ('4060', 0.19069557328620532),
#  ('4073', 0.1257377756119629),
#  ('40acr', 0.316886509082864),
#  ('40g', 0.4849451953404376),
#  ('40k', 0.31568695560504095),
#  ('40person', 0.2844192556167386),
#  ('40ton', 0.23246482428127463),
#  ('41', 1.0189808371287485),
#  ('4121922', 0.09414597112306322),
#  ('41424km2', 0.125819392905698),
#  ('41593', 0.125819392905698),
#  ('42', 0.8647212856769853),
#  ('424m', 0.2521698470979594),
#  ('425', 0.23570707864863752),
#  ('429', 0.2281340810995281),
#  ('42nd', 0.44767982330632067),
#  ('42point', 0.14384302913530006),
#  ('43', 2.801956074194672),
#  ('438', 0.1513360843085803),
#  ('44', 0.6489866414376909),
#  ('440', 0.42109386066311555),
#  ('442nd', 0.12583258070274692),
#  ('443httpyoutubeous9mm8xbbw', 0.3223958418519641),
#  ('449313', 0.06316530580599404),
#  ('44b', 0.15568111727799236),
#  ('44d', 0.7071067811865475),
#  ('45', 5.344991723109429),
#  ('4500httpsfasorgissuesnuclearweaponsstatusworldnuclearforc',
#   0.0324887455081973),
#  ('450k', 0.42169113180213497),
#  ('45th', 0.4077447043097037),
#  ('46', 2.1455228318968484),
#  ('4615', 0.125819392905698),
#  ('4648', 0.33793128307267617),
#  ('46th', 0.11722095867696308),
#  ('47', 2.1721372266157184),
#  ('473', 0.4602638689480977),
#  ('47500', 0.2399873579225236),
#  ('478', 0.07774808979240357),
#  ('47m', 0.09359373164897127),
#  ('48', 3.0584173189679946),
#  ('4842', 0.11005876465509574),
#  ('486', 0.06316530580599404),
#  ('48m', 0.09359373164897127),
#  ('48th', 0.31592746972709845),
#  ('49', 2.558342766720318),
#  ('491', 0.4943914445300117),
#  ('499', 0.1331771853295892),
#  ('49yearold', 0.3211315064495289),
#  ('4b', 0.15568111727799236),
#  ('4chan', 3.9098843535856638),
#  ('4cylind', 0.27274470455559496),
#  ('4d', 2.0901458924673424),
#  ('4edgy8m', 0.6688365435447238),
#  ('4gallon', 0.09296864696245923),
#  ('4httpwwwpoliticususacom20170203trumpbustedbigliegovernmentadmitscourt100000impactedmuslimbanhtml',
#   0.03162041164366316),
#  ('4k', 0.4717730938070109),
#  ('4m', 0.6485600705610886),
#  ('4th', 3.046688517698923),
#  ('4to1', 0.2578260172223853),
#  ('4vote', 0.06316530580599404),
#  ('4way', 0.33765735069537545),
#  ('50', 19.19340958363433),
#  ('500', 3.9736893791275856),
#  ('5000', 1.1013550141924053),
#  ('50000', 1.5618151687691468),
#  ('500000', 1.9571932858417647),
#  ('500040000', 0.25140968484710086),
#  ('5000squarefoot', 0.15617469330678463),
#  ('500k', 0.42929755142044396),
#  ('500kday', 0.43143730916613726),
#  ('500page', 0.056132205074318556),
#  ('501', 0.24868191054138236),
#  ('501c', 0.11555192479990425),
#  ('501c3', 0.0948663823065665),
#  ('501c4', 0.21403327309536943),
#  ('502', 0.25217061417621334),
#  ('5050', 1.8629790799259334),
#  ('5055', 0.3185327926455721),
#  ('5060', 0.442689579651964),
#  ('50cal', 0.40522299381323196),
#  ('50k', 3.3248335324067),
#  ('50state', 0.08238536088875478),
#  ('50th', 0.08583100150306522),
#  ('50x', 0.23731352179722925),
#  ('51', 1.972640275662087),
#  ('510', 0.7842751977218165),
#  ('513', 0.048284590295704186),
#  ('515', 0.7036782936070368),
#  ('51k', 0.09359373164897127),
#  ('52', 1.421383006820106),
#  ('523', 0.1934031226184337),
#  ('525', 0.1934031226184337),
#  ('5270', 0.09365056051231954),
#  ('53', 0.8993608009684768),
#  ('536', 0.125819392905698),
#  ('537', 0.2391500583592201),
#  ('537000', 0.19728261319401336),
#  ('538', 6.463175797334166),
#  ('538httpfivethirtyeightcomfeatureswhyfivethirtyeightgavetrumpabetterchancethanalmostanyoneels',
#   0.47630157499030706),
#  ('538httpfivethirtyeightcomliveblog2016electionresultscoverageexcid538twitt',
#   0.15862124995105087),
#  ('53k', 0.285484245067418),
#  ('54', 1.8431824319919001),
#  ('540k', 0.14830335311045725),
#  ('544k', 0.06316530580599404),
#  ('545', 0.2428984666840516),
#  ('545am', 0.2435409246432888),
#  ('54k', 0.09359373164897127),
#  ('55', 2.5514604547553783),
#  ('550', 0.6425968917655009),
#  ('5516', 0.1802060588246602),
#  ('552', 0.23580520584420825),
#  ('5543', 0.7722287938172616),
#  ('56', 1.1962754237004682),
#  ('560', 0.12583258070274692),
#  ('569', 0.06464931824525134),
#  ('56m', 0.1982423843784475),
#  ('57', 2.340608072954593),
#  ('573', 0.07506160952016319),
#  ('576', 0.06464931824525134),
#  ('577', 0.23580520584420825),
#  ('57th', 0.11722095867696308),
#  ('58', 1.1802014073206468),
#  ('580746341220006', 0.18793324815198387),
#  ('582658', 0.15055219991530627),
#  ('59', 1.0141450317630154),
#  ('594', 0.19861367413886427),
#  ('59th', 0.14215607514803022),
#  ('5d', 0.3669708942873715),
#  ('5hr', 0.36731533185096643),
#  ('5m', 0.6364191834110288),
#  ('5minut', 0.4374972111624396),
#  ('5second', 0.06264498625004862),
#  ('5th', 2.8214475887945945),
#  ('60', 9.246597715999433),
#  ('600', 0.2891518968854543),
#  ('6000', 1.7434335747561924),
#  ('60000', 0.9203021907371292),
#  ('600000', 0.9897615261032205),
#  ('60000000', 0.7685620519189251),
#  ('6001000', 0.22532461950597543),
#  ('600k', 0.13941960349308113),
#  ('6040', 1.4924669354054554),
#  ('6071', 0.31777614432992973),
#  ('607pm', 0.23296152964882688),
#  ('60bil', 0.15770836353351614),
#  ('60k', 0.5384483481663692),
#  ('60m', 0.7768419356846293),
#  ('60s70', 0.4130126709389392),
#  ('60shttpimgurcoma6jq5o', 0.09284115295863346),
#  ('60someth', 0.19967723400521345),
#  ('61', 0.22528747748437655),
#  ('610236559131169', 0.18793324815198387),
#  ('6108', 0.20657387671654118),
#  ('614', 0.14589541991530966),
#  ('617', 0.20479801101521647),
#  ('62', 0.301337825445123),
#  ('62235295', 0.10123149930026225),
#  ('6240788662972578', 0.18793324815198387),
#  ('626630', 0.15055219991530627),
#  ('629', 1.039439026038124),
#  ('62k', 0.09359373164897127),
#  ('62m', 0.2003384139974977),
#  ('63', 1.9143789435111187),
#  ('630', 0.23580520584420825),
#  ('63148555', 0.20343351515308195),
#  ('64', 0.5513637345126878),
#  ('640', 0.20343351515308195),
#  ('64235478', 0.10123149930026225),
#  ('644', 0.14589541991530966),
#  ('646449', 0.15055219991530627),
#  ('64917448', 0.13414420824484916),
#  ('64dd', 0.5773502691896257),
#  ('64k', 0.09359373164897127),
#  ('65', 1.8786785643329234),
#  ('650', 1.1050641413822224),
#  ('6500', 0.30272108025150674),
#  ('65000', 0.42489144072986806),
#  ('650000', 0.9817963688609961),
#  ('650m', 0.2521698470979594),
#  ('6535', 0.07230609933632551),
#  ('656am', 0.31087896066574117),
#  ('658', 0.20479801101521647),
#  ('659', 0.20565553289676158),
#  ('65915795', 0.13414420824484916),
#  ('66', 1.8164184438914746),
#  ('666', 0.22915301950822084),
#  ('6695', 0.3582270441490092),
#  ('66m', 0.43575482644452673),
#  ('67', 2.389130493557435),
#  ('67500000', 0.12955362099684603),
#  ('67httpswwwwashingtonpostcomnewsthefixwp20130123recordhighforhillaryclintonasshefaceslittleregardedcongress',
#   0.1339748578928289),
#  ('67k', 0.09359373164897127),
#  ('68', 0.9803670795866672),
#  ('6800', 0.09426926175172771),
#  ('68262', 0.09867065317592356),
#  ('6850year', 0.19992931655604704),
#  ('6885', 0.06526402620895827),
#  ('69', 1.2905588259414822),
#  ('6970httpwwwtandfonlinecomdoifull1010800096340220161145901',
#   0.0324887455081973),
#  ('69th', 0.24734445481862052),
#  ('6in10', 0.12715292484976773),
#  ('6k', 0.09359373164897127),
#  ('6month', 0.23706704425093472),
#  ('6th', 1.5428339817349814),
#  ('70', 9.531455704064252),
#  ('700', 0.8683587154003629),
#  ('7000', 1.923296397374369),
#  ('70000', 0.6046653292169598),
#  ('700b', 0.12164599400849184),
#  ('700k', 0.3044999042289779),
#  ('700m', 0.2546354028434989),
#  ('7046', 0.27663584137103847),
#  ('7050', 0.5494317879740436),
#  ('7063', 0.125819392905698),
#  ('7080', 0.10448924849950167),
#  ('7090', 0.2729890511606701),
#  ('70k', 0.5687798628069635),
#  ('70m', 0.2003384139974977),
#  ('70yearold', 0.35848926982340273),
#  ('71', 1.8308980295219501),
#  ('710', 0.2017377212071628),
#  ('71000', 0.20307944072866996),
#  ('72', 0.8718171438536504),
#  ('721', 0.05063083414986515),
#  ('723393', 0.15055219991530627),
#  ('725', 0.9265634921885371),
#  ('72716', 0.2630408409191691),
#  ('7281922', 0.09414597112306322),
#  ('73', 2.1098809543006913),
#  ('730', 0.37599446931780334),
#  ('732pm', 0.31087896066574117),
#  ('735132', 0.15055219991530627),
#  ('736', 0.0324887455081973),
#  ('737', 0.1378865997252259),
#  ('7384bjdoeu7863', 0.13245467154923465),
#  ('739', 0.32106936631137273),
#  ('7478the', 0.123879710706449),
#  ('7482', 0.17440448330411995),
#  ('74httpswwwscribdcomfullscreen69765861accesskeykey1wzpikwzuir39w8uxutgampstartpage52',
#   0.15161314887571284),
#  ('75', 3.424987228654606),
#  ('750k', 0.2543762209852377),
#  ('751', 0.05804993024463059),
#  ('754', 0.4845886491527211),
#  ('7580', 0.31777614432992973),
#  ('75billion', 0.45233875092474224),
#  ('75k', 0.3130953289090843),
#  ('75m', 0.08577408389240598),
#  ('7643107', 0.10123149930026225),
#  ('77', 0.36652913440879403),
#  ('78', 1.5230299061422303),
#  ('780', 0.04219739676244988),
#  ('784000', 0.08366034999796579),
#  ('785000', 0.10896628889363504),
#  ('79', 1.0042822904536532),
#  ('793', 0.16217589815978672),
#  ('793f', 0.394402471647245),
#  ('795', 0.10883988288105306),
#  ('7b', 0.15568111727799236),
#  ('7mil', 0.2609414618090576),
#  ('7minut', 0.11932289049751407),
#  ('7th', 1.4692903695467905),
#  ('80', 12.564856144809866),
#  ('800', 1.833289808781134),
#  ('8000', 0.5987384972933378),
#  ('80000', 0.06711800087493142),
#  ('800000', 0.20751755975142575),
#  ('800k', 0.5387111576247224),
#  ('800k1m', 0.5919687775503097),
#  ('800mo', 0.13941960349308113),
#  ('8020', 0.7259806870162817),
#  ('8090', 0.4126615820679142),
#  ('80k', 2.4015502933253314),
#  ('80month', 0.043715733764776776),
#  ('80searli', 0.17125062698142116),
#  ('81', 1.891977204730075),
#  ('810', 0.27955789596415237),
#  ('810m', 0.40127904857778496),
#  ('824', 0.27575584693371047),
#  ('83', 0.44335406982097036),
#  ('832', 0.1378865997252259),
#  ('835', 0.06316530580599404),
#  ('844877', 0.15055219991530627),
#  ('85', 1.1208094343968833),
#  ('852000', 0.6184441693067878),
#  ('86', 0.25819855632447564),
#  ('862', 0.07506160952016319),
#  ('8693', 0.125819392905698),
#  ('86d', 0.3554495269905964),
#  ('86not', 0.08528341417625877),
#  ('87', 0.1716721640082196),
#  ('8750', 0.35505968888580386),
#  ('88', 0.3084301034925643),
#  ('8800', 0.3120291245466509),
#  ('896', 0.07506160952016319),
#  ('8am', 0.14385810246720776),
#  ('8b', 0.15568111727799236),
#  ('8d', 0.6467666404981053),
#  ('8httpsmedia1britannicacomebmedia06380600404362630jpg', 0.1934031226184337),
#  ('8ish', 0.09656088729735444),
#  ('8k', 0.14534931020670974),
#  ('8th', 3.613215570836844),
#  ('8x', 0.14098523659879283),
#  ('8year', 0.2842370485626327),
#  ('8yearold', 0.2980174161218052),
#  ('8yr', 0.5442617211191977),
#  ('90', 12.789473492769332),
#  ('900', 1.0023091268805837),
#  ('9000', 0.29606407219449954),
#  ('900b', 0.12164599400849184),
#  ('900k', 0.13941960349308113),
#  ('9010', 0.2433175386243569),
#  ('9095', 0.15987721969769306),
#  ('90th', 0.4992103462642422),
#  ('91', 0.2963951770884815),
#  ('910', 1.492287144207615),
#  ('911', 10.33231326979632),
#  ('912', 0.6967084412681415),
#  ('915', 0.4610912525378765),
#  ('916', 0.13801573624268001),
#  ('92', 0.9930138628320544),
#  ('925749', 0.15055219991530627),
#  ('92f', 0.3166428295519095),
#  ('93', 1.0668115968251763),
#  ('933', 0.045291464595184315),
#  ('94', 0.4720857342410658),
#  ('9404', 0.06821831596171829),
#  ('943', 0.277082867816016),
#  ('946', 0.06874351681367162),
#  ('948', 0.06874351681367162),
#  ('9486', 0.12583258070274692),
#  ('95', 2.7194530281320075),
#  ('950', 0.15298243494623362),
#  ('95er', 0.07769519206355108),
#  ('96', 0.7673692264962853),
#  ('968440', 0.06316530580599404),
#  ('97', 0.7225153857105624),
#  ('979', 0.07506160952016319),
#  ('98', 1.613493800646781),
#  ('982', 0.4952853222300076),
#  ('98300', 0.3745613236897819),
#  ('984', 0.045291464595184315),
#  ('99', 6.885364010507116),
#  ('99000', 0.39439955580994246),
#  ('99110', 0.3399276318426165),
#  ('992', 0.07506160952016319),
#  ('997', 0.5833502987714205),
#  ('999', 0.2404961670294037),
#  ('9999', 0.09323780892921874),
#  ('999999', 0.25511638732116537),
#  ('9hr', 0.20769305092592005),
#  ('9httpgovinfolibraryuntedutaxreformpanelfinalreportindexhtml',
#   0.04219739676244988),
#  ('9month', 0.41079994158479116),
#  ('9th', 2.4259126304768905),
#  ('aa', 1.1014759635560762),
#  ('aaa', 0.5231806073309433),
#  ('aaaaaaaaaaa', 1.0),
#  ('aaaaaaaaaand', 0.5816772826088703),
#  ('aaaaaaaahahahahaha', 0.7071067811865475),
#  ('aaaaaand', 0.5410019748582507),
#  ('aaaaanndddit', 0.3743550911921486),
#  ('aaaaannnnndddh', 0.3743550911921486),
#  ('aaaand', 0.7352538510785775),
#  ('aaand', 0.5034411369892259),
#  ('aaron', 0.20693647925590664),
#  ...]

# %% [markdown]
# For the three techniques in problem (2) above, give an example where each would be useful.
#
# 1. Word-count vector
#
# This technique is useful with categorical data that does not have a sort of ordering (nominal). In terms of application, since it gives us counts for the terms in a document, we can use those counts to compare documents and gauge how similar they are based on the number of times words appear (or don't appear) in them. It can be used as a form of document classification.
#
# 2. Part-of-speech tag vector
#
# This technique is especially useful with decoding words that can have different parts-of-speech in a language. For example, the word "help" can be both a verb and a noun in English. Therefore, by having this tagging, we can more fully understand what the word is representing in the document and give it more linguistic understanding.
#
# 3. TF-IDF feature matrix
#
# This technique can be used in visualizations for depicting documents in relation to their most distinctive keywords. It can give meaning to a document in an appealing and easy-to-understand way by knowing the terms in a document that are distinctively frequent in a dcoument, when that document is compared with other documents.
